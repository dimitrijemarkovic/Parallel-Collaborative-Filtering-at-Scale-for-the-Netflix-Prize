# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pivot-table3-csv/pivot_table (1).csv

# %%
from surprise import Dataset, Reader, SVD, accuracy
from surprise.model_selection import train_test_split
import pandas as pd
import time
import gc
import pickle  

# Učitavanje pivot tabele iz CSV fajla i transformacija podataka u format za Surprise biblioteku
df_pivot = pd.read_csv('/kaggle/input/pivot-table3-csv/pivot_table (1).csv', index_col=0)
# 'stack()' pretvara kolone u redove tako da svaka ocena dobija sopstveni red
df_melt = df_pivot.stack().reset_index().rename(columns={'level_1': 'Movie_Id', 0: 'Rating'})

# Definisanje čitača koji govori da su ocene u opsegu od 1 do 5
reader = Reader(rating_scale=(1, 5))

# Kreiramo dataset iz tri kolone: Cust_Id, Movie_Id i Rating
data = Dataset.load_from_df(df_melt[['Cust_Id', 'Movie_Id', 'Rating']], reader)

# Delimo podatke na trening i test skupove (25% podataka je u test skupu)
trainset, testset = train_test_split(data, test_size=0.25)

# Definišemo različite vrednosti parametara koje ćemo testirati u grid search-u
n_factors_values = [10, 20, 30]  # Broj latentnih faktora (dimenzije matrice)
n_epochs_values = [10, 20, 30]   
lr_all_values = [0.002, 0.005, 0.01]  
reg_all_values = [0.02, 0.1, 0.2]     

# Promenljive za praćenje najboljeg modela
best_rmse = float('inf')  
best_params = None  
best_model = None  

# Iteracija kroz sve kombinacije parametara (grid search)
for n_factors in n_factors_values:
    for n_epochs in n_epochs_values:
        for lr_all in lr_all_values:
            for reg_all in reg_all_values:
                
                # Kreiramo SVD model sa trenutnim setom parametara
                algo = SVD(n_factors=n_factors, n_epochs=n_epochs, lr_all=lr_all, reg_all=reg_all)
                
                # Treniranje modela i merenje vremena treniranja
                start_time = time.time()
                algo.fit(trainset)
                end_time = time.time()
                print(f"Parametri: n_factors={n_factors}, n_epochs={n_epochs}, lr_all={lr_all}, reg_all={reg_all}")
                print(f"Vreme fitovanja: {end_time - start_time:.2f} sekundi")
                
                # Testiranje modela na test skupu i merenje vremena predikcije
                start_time = time.time()
                predictions = algo.test(testset)
                end_time = time.time()
                print(f"Vreme predviđanja: {end_time - start_time:.2f} sekundi")
                
                
                rmse = accuracy.rmse(predictions, verbose=False)
                mae = accuracy.mae(predictions, verbose=False)
                print(f'RMSE: {rmse}, MAE: {mae}')
                
                
                if rmse < best_rmse:
                    best_rmse = rmse
                    best_params = (n_factors, n_epochs, lr_all, reg_all)
                    best_model = algo
                    
            
                del algo
                gc.collect()

                print('-' * 50)

# Čuvanje najboljeg modela u fajl
if best_model:
    with open('best_model.pkl', 'wb') as f:
        pickle.dump(best_model, f)
    
    # Prikaz najboljih parametara i najboljeg RMSE
    print(f"Najbolji parametri: n_factors={best_params[0]}, n_epochs={best_params[1]}, lr_all={best_params[2]}, reg_all={best_params[3]}")
    print(f"Najbolji RMSE: {best_rmse}")
# Out:
# Parametri: n_factors=10, n_epochs=10, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 55.16 sekundi
# Vreme predviđanja: 50.80 sekundi
# RMSE: 0.9184846570747963, MAE: 0.724866228921748
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 49.04 sekundi
# Vreme predviđanja: 39.41 sekundi
# RMSE: 0.9206949178587659, MAE: 0.7290269577357712
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 49.17 sekundi
# Vreme predviđanja: 39.09 sekundi
# RMSE: 0.9239681142103124, MAE: 0.7343532094625029
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 49.69 sekundi
# Vreme predviđanja: 39.28 sekundi
# RMSE: 0.8895935464179726, MAE: 0.6959249290135513
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 49.11 sekundi
# Vreme predviđanja: 39.21 sekundi
# RMSE: 0.9158134070404749, MAE: 0.7213830594319167
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 49.19 sekundi
# Vreme predviđanja: 39.42 sekundi
# RMSE: 0.9189070312228648, MAE: 0.7269885310195666
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 49.35 sekundi
# Vreme predviđanja: 39.38 sekundi
# RMSE: 0.8751594199949116, MAE: 0.6812097111610943
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 49.51 sekundi
# Vreme predviđanja: 39.29 sekundi
# RMSE: 0.9157122987979303, MAE: 0.7202330189827786
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=10, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 49.41 sekundi
# Vreme predviđanja: 39.38 sekundi
# RMSE: 0.9197260594403696, MAE: 0.7268491440821724
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 98.46 sekundi
# Vreme predviđanja: 39.10 sekundi
# RMSE: 0.9013018753277724, MAE: 0.7076491962440292
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 98.55 sekundi
# Vreme predviđanja: 39.19 sekundi
# RMSE: 0.9152067339013684, MAE: 0.7219002262694172
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 98.41 sekundi
# Vreme predviđanja: 39.35 sekundi
# RMSE: 0.9184494093072638, MAE: 0.7274536933924263
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 98.26 sekundi
# Vreme predviđanja: 39.19 sekundi
# RMSE: 0.8734381395436449, MAE: 0.680474034038621
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 98.00 sekundi
# Vreme predviđanja: 38.86 sekundi
# RMSE: 0.9138258401289034, MAE: 0.7190203386427421
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 97.22 sekundi
# Vreme predviđanja: 38.80 sekundi
# RMSE: 0.9180843866905652, MAE: 0.7257573463625347
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 97.55 sekundi
# Vreme predviđanja: 38.68 sekundi
# RMSE: 0.8725502593533888, MAE: 0.6754792925035196
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 98.13 sekundi
# Vreme predviđanja: 38.89 sekundi
# RMSE: 0.8988422895506845, MAE: 0.7064785015060309
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=20, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 98.01 sekundi
# Vreme predviđanja: 38.80 sekundi
# RMSE: 0.9195627790322444, MAE: 0.7268657538645426
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 146.12 sekundi
# Vreme predviđanja: 38.94 sekundi
# RMSE: 0.882423850545212, MAE: 0.6903250880201022
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 147.16 sekundi
# Vreme predviđanja: 38.85 sekundi
# RMSE: 0.9142242702093526, MAE: 0.7202580858958443
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 146.98 sekundi
# Vreme predviđanja: 38.93 sekundi
# RMSE: 0.9173683362947473, MAE: 0.7258542451444112
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 146.29 sekundi
# Vreme predviđanja: 38.80 sekundi
# RMSE: 0.867613138215519, MAE: 0.6739088257012888
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 146.68 sekundi
# Vreme predviđanja: 38.75 sekundi
# RMSE: 0.9055677793439815, MAE: 0.7122689220653667
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 146.53 sekundi
# Vreme predviđanja: 38.87 sekundi
# RMSE: 0.9179990090987096, MAE: 0.7257312031749706
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 146.82 sekundi
# Vreme predviđanja: 38.59 sekundi
# RMSE: 0.8776866437017571, MAE: 0.678392104760769
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 145.49 sekundi
# Vreme predviđanja: 38.70 sekundi
# RMSE: 0.890543868583932, MAE: 0.6998863866324034
# --------------------------------------------------
# Parametri: n_factors=10, n_epochs=30, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 147.85 sekundi
# Vreme predviđanja: 38.64 sekundi
# RMSE: 0.9195195284539079, MAE: 0.7269234385734515
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 51.80 sekundi
# Vreme predviđanja: 38.87 sekundi
# RMSE: 0.9179312880092337, MAE: 0.7243815663724682
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 52.18 sekundi
# Vreme predviđanja: 39.34 sekundi
# RMSE: 0.9207022433642845, MAE: 0.7290333993174943
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 52.00 sekundi
# Vreme predviđanja: 39.08 sekundi
# RMSE: 0.9239687636599516, MAE: 0.7343542149812418
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 52.05 sekundi
# Vreme predviđanja: 38.97 sekundi
# RMSE: 0.8880136955079316, MAE: 0.6944182635722117
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 51.98 sekundi
# Vreme predviđanja: 39.50 sekundi
# RMSE: 0.9157861830886725, MAE: 0.721359558657229
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 52.16 sekundi
# Vreme predviđanja: 39.88 sekundi
# RMSE: 0.918907450582501, MAE: 0.7269902229929128
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 52.25 sekundi
# Vreme predviđanja: 39.08 sekundi
# RMSE: 0.8738609234124192, MAE: 0.6796986788438292
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 52.31 sekundi
# Vreme predviđanja: 38.65 sekundi
# RMSE: 0.9156344962353388, MAE: 0.720192214079583
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=10, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 52.16 sekundi
# Vreme predviđanja: 38.87 sekundi
# RMSE: 0.9197248809543689, MAE: 0.7268482643008359
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 103.79 sekundi
# Vreme predviđanja: 38.54 sekundi
# RMSE: 0.8934353639635475, MAE: 0.7006484143662205
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 103.69 sekundi
# Vreme predviđanja: 38.98 sekundi
# RMSE: 0.9152118414459465, MAE: 0.721903902752716
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 104.84 sekundi
# Vreme predviđanja: 38.94 sekundi
# RMSE: 0.9184497440854595, MAE: 0.7274534350378214
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 105.35 sekundi
# Vreme predviđanja: 39.08 sekundi
# RMSE: 0.8714659610454127, MAE: 0.6786355279095972
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 104.01 sekundi
# Vreme predviđanja: 38.88 sekundi
# RMSE: 0.9131980677249667, MAE: 0.7185046940469562
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 104.26 sekundi
# Vreme predviđanja: 38.98 sekundi
# RMSE: 0.9180848367416802, MAE: 0.7257584555768208
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 105.67 sekundi
# Vreme predviđanja: 39.17 sekundi
# RMSE: 0.8783655004869596, MAE: 0.678988215093303
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 105.73 sekundi
# Vreme predviđanja: 39.65 sekundi
# RMSE: 0.8982972144498822, MAE: 0.7060572764086666
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=20, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 105.55 sekundi
# Vreme predviđanja: 39.12 sekundi
# RMSE: 0.9195654890324931, MAE: 0.7268680714060041
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 158.23 sekundi
# Vreme predviđanja: 39.27 sekundi
# RMSE: 0.8823127237440193, MAE: 0.6901265405396494
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 157.85 sekundi
# Vreme predviđanja: 39.35 sekundi
# RMSE: 0.9142238828335661, MAE: 0.7202593223401155
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 157.80 sekundi
# Vreme predviđanja: 39.48 sekundi
# RMSE: 0.9173688586792912, MAE: 0.7258548216750557
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 157.89 sekundi
# Vreme predviđanja: 38.77 sekundi
# RMSE: 0.868496235260365, MAE: 0.6736823958871552
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 156.99 sekundi
# Vreme predviđanja: 39.12 sekundi
# RMSE: 0.8996934251203821, MAE: 0.707402315769019
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 156.52 sekundi
# Vreme predviđanja: 39.12 sekundi
# RMSE: 0.9179957034091547, MAE: 0.7257288639739115
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 156.47 sekundi
# Vreme predviđanja: 39.27 sekundi
# RMSE: 0.891129316677361, MAE: 0.6873350510236205
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 157.31 sekundi
# Vreme predviđanja: 38.93 sekundi
# RMSE: 0.8896378370324798, MAE: 0.6991748355427236
# --------------------------------------------------
# Parametri: n_factors=20, n_epochs=30, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 157.63 sekundi
# Vreme predviđanja: 38.91 sekundi
# RMSE: 0.9194755415672106, MAE: 0.726890045481768
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 56.61 sekundi
# Vreme predviđanja: 39.36 sekundi
# RMSE: 0.9178134066238111, MAE: 0.7242792945902302
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 56.39 sekundi
# Vreme predviđanja: 39.39 sekundi
# RMSE: 0.9207016388006541, MAE: 0.7290364375847721
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 56.50 sekundi
# Vreme predviđanja: 39.49 sekundi
# RMSE: 0.9239715990446634, MAE: 0.7343572740575429
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 56.60 sekundi
# Vreme predviđanja: 39.27 sekundi
# RMSE: 0.8871431605493906, MAE: 0.6936850186663764
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 56.74 sekundi
# Vreme predviđanja: 39.32 sekundi
# RMSE: 0.9157782837295962, MAE: 0.7213586618329519
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 56.34 sekundi
# Vreme predviđanja: 39.12 sekundi
# RMSE: 0.9189097312745728, MAE: 0.7269934891978501
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 56.18 sekundi
# Vreme predviđanja: 39.03 sekundi
# RMSE: 0.8738436507890103, MAE: 0.679558351520786
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 56.02 sekundi
# Vreme predviđanja: 38.98 sekundi
# RMSE: 0.9151028279300365, MAE: 0.7197584887687508
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=10, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 55.86 sekundi
# Vreme predviđanja: 38.85 sekundi
# RMSE: 0.9197251558324168, MAE: 0.7268501040808728
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 111.88 sekundi
# Vreme predviđanja: 39.00 sekundi
# RMSE: 0.8924584547473278, MAE: 0.6998277118270779
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 112.15 sekundi
# Vreme predviđanja: 38.96 sekundi
# RMSE: 0.9152086386760724, MAE: 0.7219014853183958
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 111.58 sekundi
# Vreme predviđanja: 38.93 sekundi
# RMSE: 0.9184527727603683, MAE: 0.727458011934936
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 112.14 sekundi
# Vreme predviđanja: 38.82 sekundi
# RMSE: 0.8691237693537274, MAE: 0.6763631718463672
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 112.30 sekundi
# Vreme predviđanja: 39.08 sekundi
# RMSE: 0.9126210150004742, MAE: 0.7180447624822288
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 112.36 sekundi
# Vreme predviđanja: 38.96 sekundi
# RMSE: 0.9180838649841265, MAE: 0.725758562269366
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 112.19 sekundi
# Vreme predviđanja: 38.94 sekundi
# RMSE: 0.8835866045780278, MAE: 0.6829747252070553
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 112.30 sekundi
# Vreme predviđanja: 39.06 sekundi
# RMSE: 0.8970422054289684, MAE: 0.7050317320716724
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=20, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 112.90 sekundi
# Vreme predviđanja: 39.03 sekundi
# RMSE: 0.9195588571820532, MAE: 0.7268641249494707
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.002, reg_all=0.02
# Vreme fitovanja: 168.72 sekundi
# Vreme predviđanja: 38.83 sekundi
# RMSE: 0.880771565645037, MAE: 0.6888092986752214
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.002, reg_all=0.1
# Vreme fitovanja: 167.63 sekundi
# Vreme predviđanja: 38.57 sekundi
# RMSE: 0.9141051335260277, MAE: 0.7201624175313454
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.002, reg_all=0.2
# Vreme fitovanja: 167.69 sekundi
# Vreme predviđanja: 38.82 sekundi
# RMSE: 0.9173692039721311, MAE: 0.7258563017121155
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.005, reg_all=0.02
# Vreme fitovanja: 167.75 sekundi
# Vreme predviđanja: 38.98 sekundi
# RMSE: 0.8704415044885773, MAE: 0.6750197094962608
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.005, reg_all=0.1
# Vreme fitovanja: 168.02 sekundi
# Vreme predviđanja: 39.19 sekundi
# RMSE: 0.899347532719594, MAE: 0.7071235082414831
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.005, reg_all=0.2
# Vreme fitovanja: 170.35 sekundi
# Vreme predviđanja: 39.25 sekundi
# RMSE: 0.9179944592859327, MAE: 0.7257282729431328
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.01, reg_all=0.02
# Vreme fitovanja: 171.05 sekundi
# Vreme predviđanja: 39.36 sekundi
# RMSE: 0.9024147875759677, MAE: 0.695947504546213
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.01, reg_all=0.1
# Vreme fitovanja: 170.91 sekundi
# Vreme predviđanja: 39.11 sekundi
# RMSE: 0.8890015589832662, MAE: 0.6988588041755628
# --------------------------------------------------
# Parametri: n_factors=30, n_epochs=30, lr_all=0.01, reg_all=0.2
# Vreme fitovanja: 172.30 sekundi
# Vreme predviđanja: 39.55 sekundi
# RMSE: 0.9194918298747748, MAE: 0.7269034946846529
# --------------------------------------------------
# Najbolji parametri: n_factors=10, n_epochs=30, lr_all=0.005, reg_all=0.02
# Najbolji RMSE: 0.867613138215519
